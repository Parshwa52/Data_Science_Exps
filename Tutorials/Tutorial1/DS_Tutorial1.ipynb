# %% [markdown]
# ## Name:- Parshwa Shah
# ## Roll No:- 34
# ## UID:- 2019230071

# %% [markdown]
# <h1><center> Tutorial 1 </center></h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('vaccination-data.csv')

# %%
dataset.head(25)
# Out:
#                              COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0                        Afghanistan  AFG       EMRO   REPORTING   2022-02-14
# 1                            Albania  ALB       EURO   REPORTING   2022-02-06
# 2                            Algeria  DZA       AFRO   REPORTING   2022-02-08
# 3                     American Samoa  ASM       WPRO   REPORTING   2022-01-28
# 4                            Andorra  AND       EURO   REPORTING   2022-01-23
# 5                             Angola  AGO       AFRO   REPORTING   2022-02-09
# 6                           Anguilla  AIA       AMRO   REPORTING   2022-02-11
# 7                Antigua and Barbuda  ATG       AMRO   REPORTING   2022-02-11
# 8                          Argentina  ARG       AMRO   REPORTING   2022-02-11
# 9                            Armenia  ARM       EURO   REPORTING   2022-01-30
# 10                             Aruba  ABW       AMRO   REPORTING   2022-02-11
# ...

# %%
dataset['COUNTRY'].value_counts()
# Out:
# Somalia                        1
# Cook Islands                   1
# Latvia                         1
# Canada                         1
# Netherlands                    1
#                               ..
# Mauritania                     1
# El Salvador                    1
# United Republic of Tanzania    1
# Nepal                          1
# Greece                         1
# Name: COUNTRY, Length: 228, dtype: int64

# %%
dataset.isna().sum()
# Out:
# COUNTRY                                  0
# ISO3                                     0
# WHO_REGION                               0
# DATA_SOURCE                              0
# DATE_UPDATED                             0
# TOTAL_VACCINATIONS                       0
# PERSONS_VACCINATED_1PLUS_DOSE            3
# TOTAL_VACCINATIONS_PER100                0
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     3
# PERSONS_FULLY_VACCINATED                 3
# PERSONS_FULLY_VACCINATED_PER100          3
# VACCINES_USED                            3
# FIRST_VACCINE_DATE                      20
# NUMBER_VACCINES_TYPES_USED               3
# dtype: int64

# %%
dataset["FIRST_VACCINE_DATE"].fillna("2021-01-01", inplace = True)

# %%
dataset.isna().sum()
# Out:
# COUNTRY                                 0
# ISO3                                    0
# WHO_REGION                              0
# DATA_SOURCE                             0
# DATE_UPDATED                            0
# TOTAL_VACCINATIONS                      0
# PERSONS_VACCINATED_1PLUS_DOSE           3
# TOTAL_VACCINATIONS_PER100               0
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    3
# PERSONS_FULLY_VACCINATED                3
# PERSONS_FULLY_VACCINATED_PER100         3
# VACCINES_USED                           3
# FIRST_VACCINE_DATE                      0
# NUMBER_VACCINES_TYPES_USED              3
# dtype: int64

# %%
dataset['VACCINES_USED'].value_counts().head(25).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='VACCINES_USED'>

# %%
dataset = dataset.dropna(axis = 0)

# %%
dataset
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2022-02-14
# 1              Albania  ALB       EURO   REPORTING   2022-02-06
# 2              Algeria  DZA       AFRO   REPORTING   2022-02-08
# 3       American Samoa  ASM       WPRO   REPORTING   2022-01-28
# 4              Andorra  AND       EURO   REPORTING   2022-01-23
# ..                 ...  ...        ...         ...          ...
# 223           Viet Nam  VNM       WPRO   REPORTING   2022-02-04
# 224  Wallis and Futuna  WLF       WPRO   REPORTING   2022-01-11
# 225              Yemen  YEM       EMRO   REPORTING   2022-02-13
# 226             Zambia  ZMB       AFRO   REPORTING   2021-11-18
# 227           Zimbabwe  ZWE       AFRO   REPORTING   2022-01-29
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0               5321308                      4723416.0
# 1               2646554                      1267908.0
# ...

# %%
dataset.isna().sum()
# Out:
# COUNTRY                                 0
# ISO3                                    0
# WHO_REGION                              0
# DATA_SOURCE                             0
# DATE_UPDATED                            0
# TOTAL_VACCINATIONS                      0
# PERSONS_VACCINATED_1PLUS_DOSE           0
# TOTAL_VACCINATIONS_PER100               0
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    0
# PERSONS_FULLY_VACCINATED                0
# PERSONS_FULLY_VACCINATED_PER100         0
# VACCINES_USED                           0
# FIRST_VACCINE_DATE                      0
# NUMBER_VACCINES_TYPES_USED              0
# dtype: int64

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x = 'ISO3',
            y = 'TOTAL_VACCINATIONS',
            data = dataset.head(25))
# Out:
# <AxesSubplot:xlabel='ISO3', ylabel='TOTAL_VACCINATIONS'>

# %%
sns.barplot(x = 'ISO3',
            y = 'TOTAL_VACCINATIONS_PER100',
            data = dataset.head(25))
# Out:
# <AxesSubplot:xlabel='ISO3', ylabel='TOTAL_VACCINATIONS_PER100'>

# %%
sns.barplot(x = 'ISO3',
            y = 'PERSONS_VACCINATED_1PLUS_DOSE_PER100',
            data = dataset.head(25))
# Out:
# <AxesSubplot:xlabel='ISO3', ylabel='PERSONS_VACCINATED_1PLUS_DOSE_PER100'>

# %%
sns.barplot(x = 'ISO3',
            y = 'PERSONS_FULLY_VACCINATED_PER100',
            data = dataset.head(25))
# Out:
# <AxesSubplot:xlabel='ISO3', ylabel='PERSONS_FULLY_VACCINATED_PER100'>
